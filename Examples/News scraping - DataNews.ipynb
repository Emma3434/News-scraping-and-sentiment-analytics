# %%
import pandas as pd
import inspect
import datanews

# %%
inspect.getargspec(datanews.news)
# Out:
# <ipython-input-34-2a85fbb51d02>:1: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   inspect.getargspec(datanews.news)
# ArgSpec(args=['q', 'from_date', 'to_date', 'source', 'country', 'language', 'topic', 'page', 'size', 'sortBy'], varargs=None, keywords=None, defaults=(None, None, None, None, None, None, None, None, None, None))

# %%
query = "Apple"
ticker = "AAPL"
from_date = "2021-03-12T09:30:00+00:00"
to_date = "2021-03-12T15:59:00+00:00"
sortBy = "date"
source = "marketwatch.com"
topic = "business"
apiKey = "4dbc17e007ab436fb66416009dfb59a8"

# %%
datanews.api_key = '0bnmoy3ll9lyxacrjlttep15n'

response = datanews.news(q = query,
                         from_date = from_date,
                         to_date = to_date,
                         country = ['us'],
                         language = ['en'],
                         topic = topic,
                         sortBy = sortBy,
                         #source = source,
                         size=100)
articles = response['hits']
df = pd.DataFrame(articles)

# %%
df
# Out:
#                                                   url                source  \
# 0   https://www.foxbusiness.com/lifestyle/apple-su...       foxbusiness.com
# 1   http://www.foxbusiness.com/lifestyle/apple-sue...       foxbusiness.com
# 2   https://au.finance.yahoo.com/news/costco-may-b...  au.finance.yahoo.com
# 3   https://finance.yahoo.com/news/reasons-why-inv...     finance.yahoo.com
# 4   https://www.fastcompany.com/90613728/tech-comp...       fastcompany.com
# 5   https://www.zacks.com/stock/news/1278255/is-we...             zacks.com
# 6   https://uk.finance.yahoo.com/news/karen-gibson...  uk.finance.yahoo.com
# 7   https://www.ibtimes.com/megan-thee-stallions-c...           ibtimes.com
# 8   https://www.cnbc.com/2021/03/12/fridays-analys...              cnbc.com
# 9   https://www.fastcompany.com/90612231/from-blin...       fastcompany.com
# 10  https://www.thestreet.com/investing/how-to-pay...         thestreet.com
# 11  https://forextv.com/top-news/ideal-image-conti...           forextv.com
# 12  https://www.reuters.com/article/usa-stocks-idU...           reuters.com
# 13  https://www.rttnews.com/3177039/apple-sues-for...           rttnews.com
# 14  https://www.rttnews.com/3177039/apple-sues-for...           rttnews.com
# 15  https://uk.finance.yahoo.com/news/cash-coins-n...  uk.finance.yahoo.com
# 16  https://www.thestreet.com/apple/stock/apple-st...         thestreet.com
#
#                           authors  \
# 0             [Daniella Genovese]
# 1             [Daniella Genovese]
# 2                   [Brian Sozzi]
# 3         [Zacks Equity Research]
# 4              [Katharine Schwab]
# 5     [Zacks Investment Research]
# 6                [Rebecca Taylor]
# 7                     [Sana Khan]
# 8                 [Michael Bloom]
# 9               [Suzanne LaBarre]
# 10                   [Paul Price]
# 11                [GlobeNewswire]
# 12  [Shashank Nayar, Medha Singh]
# 13         [RTTNews Staff Writer]
# 14         [RTTNews Staff Writer]
# 15                [Suban Abdulla]
# 16               [Daniel Martins]
#
#                                                 title  \
# 0   Apple sues former employee over leaking trade ...
# 1   Apple sues former employee over leaking trade ...
# 2   Costco may be 'poised' to increase membership ...
# 3   Reasons Why Investors Should Hold Radian Group...
# 4   How tech companies can work with HBCUs to impr...
# 5   Is Western Midstream Partners (WES) a Great St...
# 6   Founder of Black choir from Harry and Meghan's...
# 7   Megan Thee Stallion's Colorful 'Beautiful Mist...
# 8   Here are Friday's biggest analyst calls of the...
# 9   Cliff Kuang on the Innovation by Design Awards...
# 10           How to Pay Taxes On Your Options Trading
# 11  Ideal Image Continues Nationwide Growth with E...
# 12  Nasdaq futures fall nearly 2% as bond yields s...
# 13  Apple Sues Former Employee For Allegedly Steal...
# 14  Apple Sues Former Employee For Allegedly Steal...
# 15  Cashless society: Cash could disappear from th...
# 16     Apple Stock: One Year Of Pandemic, 78% Returns
#
#                       pubDate country language  \
# 0   2021-03-12T15:32:14+00:00      us       en
# 1   2021-03-12T15:32:14+00:00      us       en
# 2   2021-03-12T14:27:49+00:00      us       en
# 3   2021-03-12T14:26:02+00:00      us       en
# 4   2021-03-12T14:00:44+00:00      us       en
# 5   2021-03-12T13:53:55+00:00      us       en
# 6   2021-03-12T13:25:12+00:00      us       en
# 7   2021-03-12T13:20:33+00:00      us       en
# 8   2021-03-12T13:03:23+00:00      us       en
# 9   2021-03-12T13:00:36+00:00      us       en
# 10  2021-03-12T13:00:00+00:00      us       en
# 11  2021-03-12T12:35:43+00:00      us       en
# 12  2021-03-12T12:33:00+00:00      us       en
# 13  2021-03-12T11:45:00+00:00      us       en
# 14  2021-03-12T11:45:00+00:00      us       en
# 15  2021-03-12T11:28:34+00:00      us       en
# 16  2021-03-12T11:02:20+00:00      us       en
#
#                                           description  \
# 0   Apple sues former employee over leaking trade ...
# 1   The suit alleges Lancaster "used his seniority...
# 2   Costco may be 'poised' to increase membership ...
# 3   Reasons Why Investors Should Hold Radian Group...
# 4   How tech companies can work with HBCUs to impr...
# 5   Is Western Midstream Partners (WES) a Great St...
# 6   Founder of Black choir from Harry and Meghan's...
# 7   Megan Thee Stallion's Colorful 'Beautiful Mist...
# 8   Here are the biggest calls on Wall Street on F...
# 9   Cliff Kuang on the Innovation by Design Awards...
# 10  How to Pay Taxes On Your Options Trading  TheS...
# 11  Ideal Image Continues Nationwide Growth with E...
# 12  Nasdaq futures fall nearly 2% as bond yields s...
# 13  Tech major Apple Inc. has sued its former mate...
# 14  Tech major Apple Inc. has sued its former mate...
# 15  Cashless society: Cash could disappear from th...
# 16  Apple Stock: One Year Of Pandemic, 78% Returns...
#
#                                              imageUrl  \
# 0   https://a57.foxnews.com/static.foxbusiness.com...
# 1   https://a57.foxnews.com/static.foxbusiness.com...
# 2   https://s.yimg.com/ny/api/res/1.2/NCBbtBJ5MeDI...
# 3   https://s.yimg.com/uu/api/res/1.2/EEUv5JQFTAI4...
# 4   https://images.fastcompany.net/image/upload/w_...
# 5   https://staticx-tuner.zacks.com/images/article...
# 6   https://s.yimg.com/ny/api/res/1.2/cSjBaXKsjtoW...
# 7   https://s1.ibtimes.com/sites/www.ibtimes.com/f...
# 8   https://image.cnbcfm.com/api/v1/image/10653375...
# 9   https://images.fastcompany.net/image/upload/w_...
# 10  https://www.thestreet.com/.image/t_share/MTc5M...
# 11  https://ml.globenewswire.com/Resource/Download...
# 12  https://s1.reutersmedia.net/resources_v2/image...
# 13  https://cdn.rttnews.com/articleimages/ustopsto...
# 14  https://cdn.rttnews.com/articleimages/ustopsto...
# 15  https://s.yimg.com/ny/api/res/1.2/1hoUquIzVdU1...
# 16  https://www.thestreet.com/.image/t_share/MTc0M...
#
#                                               content
# 0   Apple sued one of its former employees on Thur...
# 1   Apple sued one of its former employees on Thur...
# 2   Costco (COST) may be about to put the burden o...
# 3   Radian Group RDN is well poised for growth, dr...
# 4   Over the past few years, we’ve seen various ef...
# 5   Value investing is easily one of the most popu...
# 6   Watch: Prince William says 'we are very much n...
# 7   Megan Thee Stallion took to Instagram on March...
# 8   A pedestrian and cyclist wear facemasks outsid...
# 9   This year, as we celebrate the awards’ 10th an...
# 10  Figuring out taxes on your options trades can ...
# 11  Leading North American Aesthetics Brand Expand...
# 12  * Three major indexes set for best week in six...
# 13  Tech major Apple Inc. has sued its former mate...
# 14  Tech major Apple Inc. has sued its former mate...
# 15  Coins and banknotes could disappear from the U...
# 16  COVID-19 has been one of the most disruptive e...
